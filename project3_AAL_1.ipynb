# %%
path = '/content/AusApparalSales4thQrt2020.csv'

# %%
import pandas as pd
from pandas import Series, DataFrame
import plotly.express as px

# %% [markdown]
# #making a dataframe

# %%
aal = pd.read_csv(path)

# %% [markdown]
# ```
#
# ```
# #<center> **First three rows** <center/>

# %%
aal.head(3)

# %% [markdown]
# #last 3 rows

# %%
aal.tail(3)

# %% [markdown]
# #informtion about the data

# %% [markdown]
# Information about the data such as datatype, columns (names and numbers), number or rows and null values

# %%
aal.info()

# %% [markdown]
# #Changing Date column to datetime datatype

# %%
aal['Date'] = pd.to_datetime(aal['Date'])
aal.info()

# %% [markdown]
# #Changing Time column to string datatype

# %%
aal['Time'] = aal['Time'].astype(str)#astype(str)#map(str)#apply(str)# did not work
aal.info()

# %%
aal.Time.unique()

# %% [markdown]
# #changing state datatype to string datatype

# %%
aal['State'] = aal['State'].astype(str)#did not work
aal.info()

# %%
aal = aal.astype({'Time':'string', 'State': 'string', 'Group': 'string'}) #worked

# %%
aal.info()

# %%
aal.columns
# Out:
# Index(['Date', 'Time', 'State', 'Group', 'Unit', 'Sales'], dtype='object')

# %% [markdown]
# #statistical analyis on numerical columns

# %% [markdown]
# using describe method

# %%
aal.describe().round(3)
# Out:
#            Unit       Sales
# count  7560.000    7560.000
# mean     18.005   45013.558
# std      12.901   32253.507
# min       2.000    5000.000
# 25%       8.000   20000.000
# 50%      14.000   35000.000
# 75%      26.000   65000.000
# max      65.000  162500.000

# %% [markdown]
# #checking for the missing values

# %%
aal.isnull().sum()
# Out:
# Date     0
# Time     0
# State    0
# Group    0
# Unit     0
# Sales    0
# dtype: int64

# %% [markdown]
# # <center> **Total sales by time (Morning/Evening/Afternoon)** <center/>

# %% [markdown]
# ##Analyzing data for the group (morning, afternoon, evening)
# ##I will use data to find the maximum, minimum, and the mean sale amount

# %%
aal.groupby('Time')['Sales'].sum()
# Out:
# Time
# Afternoon    114007500
# Evening      112087500
# Morning      114207500
# Name: Sales, dtype: int64

# %% [markdown]
# # A histogram is used to show the Total sale by time

# %%
px.histogram(aal, x = 'Time', y = 'Sales', title = 'Total Sales by Time', template = 'plotly_dark', text_auto = True, color = 'Time')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Mean, max, min sale by time (mornig/afternoon/evening)

# %%
pd.pivot_table(aal, index = 'Time', values = 'Sales', aggfunc = ['mean', 'max', 'min']).round(3)
# Out:
#                 mean     max   min
#                Sales   Sales Sales
# Time
# Afternoon  45241.071  162500  5000
# Evening    44479.167  162500  5000
# Morning    45320.437  162500  5000

# %% [markdown]
# #Average sale by time (morning/afternoon/evenning)

# %% [markdown]
# ##A histogram is used to show the average sale by time.

# %%
fig = px.histogram(aal, x="Time", y="Sales", histfunc='avg', color = 'Time', text_auto = True, template = 'plotly_white', title = 'Average Sale by Time')

fig.update_layout(
    width=1400,
    height=650
    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Total Sale Revenue by state

# %%
pd.pivot_table(aal, index = ['State', 'Time'], values = 'Sales', aggfunc = 'sum').sort_values(by = 'Sales', ascending = False)
# Out:
#                     Sales
# State Time
# VIC   Morning    35622500
#       Afternoon  35062500
#       Evening    34880000
# NSW   Morning    25147500
#       Afternoon  25110000
#       Evening    24712500
# SA    Afternoon  20025000
#       Morning    19465000
#       Evening    19367500
# QLD   Morning    11437500
#       Afternoon  11347500
#       Evening    10632500
# TAS   Afternoon   7670000
# NT    Evening     7627500
# WA    Morning     7567500
# TAS   Evening     7565000
#       Morning     7525000
# NT    Afternoon   7510000
#       Morning     7442500
# WA    Evening     7302500
#       Afternoon   7282500

# %% [markdown]
# #Total Sale Revenue by State and time.

# %%
px.histogram(aal, x = 'State', y = 'Sales', color = 'Time', title = 'Total Sale by State and Time', template='presentation', text_auto = True )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Sales by State (as percent)

# %%
px.pie(aal, values = 'Sales', names = 'State', title = 'Sales by State', template = 'plotly_dark', height = 780)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Total Sales by time/group (kids, men, women, seniors)

# %%
pd.pivot_table(aal, index = 'Time', columns = 'Group', values = 'Sales', aggfunc = 'sum')
# Out:
# Group       Kids      Men       Seniors   Women
# Time
# Afternoon  28502500  28767500  28195000  28542500
# Evening    28052500  28222500  27267500  28545000
# Morning    28517500  28760000  28575000  28355000

# %% [markdown]
# #Total Sales by time/group (kids, men, women, seniors) chart

# %%
fig = px.histogram(aal, x = 'Time', y = 'Sales', color = 'Group', text_auto = True, title = 'Sales by Time/Group', template = 'plotly_dark')
fig.update_layout(
    width=1400,
    height=750
    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #State/Group/total sale

# %% [markdown]
# ##Total Sales Analysis by State and Groups (Kids, Women, Men, and

# %%
pd.pivot_table(aal, index = ['State', 'Group'], values=['Sales'], aggfunc='sum')
# Out:
#                   Sales
# State Group
# NSW   Kids     18587500
#       Men      19022500
#       Seniors  18187500
#       Women    19172500
# NT    Kids      5700000
#       Men       5762500
#       Seniors   5465000
#       Women     5652500
# QLD   Kids      8510000
#       Men       8392500
#       Seniors   8190000
#       Women     8325000
# SA    Kids     14515000
#       Men      14655000
#       Seniors  14717500
#       Women    14970000
# TAS   Kids      5775000
#       Men       5757500
#       Seniors   5650000
#       Women     5577500
# VIC   Kids     26360000
#       Men      26407500
#       Seniors  26315000
#       Women    26482500
# WA    Kids      5625000
#       Men       5752500
#       Seniors   5512500
#       Women     5262500

# %%
fig = px.histogram(aal, x = 'Group', y = 'Sales', color = 'State', title = 'Sales by State/Group', template = 'plotly_white', text_auto = True )
fig.update_layout(
    width=1400,
    height=665
    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Sales by State/Group chart

# %%
px.histogram(aal, x = 'State', y = 'Sales', color = 'Group', title = 'Sales by State/Group', template = 'plotly_white', text_auto = True )

# %% [markdown]
# #State with the highest/lowest sale

# %%
aal.groupby('State')['Sales'].sum().sort_values(ascending = False)
# Out:
# State
# VIC    105565000
# NSW     74970000
# SA      58857500
# QLD     33417500
# TAS     22760000
# NT      22580000
# WA      22152500
# Name: Sales, dtype: int64

# %%
fig = px.histogram(aal, x = 'State', y = 'Sales', color = 'Group', title = 'Highest/Lowest Sales by State', template = 'plotly_white', text_auto = True )
fig.update_layout(
    width=1400,
    height=655
    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Units vs. Sales

# %%
aal.groupby('Unit')['Sales'].sum().sort_values(ascending = False)
# Out:
# Unit
# 15    12600000
# 14    10640000
# 13    10335000
# 10    10050000
# 25    10000000
#         ...
# 53     1192500
# 51     1147500
# 60     1050000
# 58      725000
# 2       650000
# Name: Sales, Length: 64, dtype: int64

# %%
px.scatter(aal, x = 'Unit', y = 'Sales', color = 'State', title = 'Units/Sales in Each State', template = 'plotly_white', size = 'Sales', height = 700)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter(aal, x = 'Time', y = 'Sales', color = 'Group', title = 'Time vs Sales', template = 'plotly_white', size = 'Sales', height = 900)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
pd.pivot_table(aal, index = ['State','Time'], columns = 'Group', values = 'Sales', aggfunc = 'sum')
# Out:
# Group            Kids     Men      Seniors  Women
# State Time
# NSW   Afternoon  6187500  6512500  5985000  6425000
#       Evening    6132500  6220000  6032500  6327500
#       Morning    6267500  6290000  6170000  6420000
# NT    Afternoon  1880000  1885000  1797500  1947500
#       Evening    1972500  1915000  1907500  1832500
#       Morning    1847500  1962500  1760000  1872500
# QLD   Afternoon  2860000  3007500  2840000  2640000
#       Evening    2715000  2540000  2592500  2785000
#       Morning    2935000  2845000  2757500  2900000
# SA    Afternoon  4970000  4760000  5092500  5202500
#       Evening    4797500  4942500  4660000  4967500
#       Morning    4747500  4952500  4965000  4800000
# TAS   Afternoon  1872500  2030000  1880000  1887500
#       Evening    1975000  1842500  1855000  1892500
#       Morning    1927500  1885000  1915000  1797500
# VIC   Afternoon  8787500  8690000  8830000  8755000
#       Evening    8622500  8900000  8427500  8930000
# ...

# %% [markdown]
# #number of units sold to each group

# %%
px.histogram(aal, x = 'Unit', color = 'Group', title = 'Units Sold by Group', template = 'presentation', text_auto = True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Number of units sold as percent to each group

# %%
px.pie(aal, values = 'Unit', names = 'Group', title = 'Units Sold by Group', template = 'plotly_dark', height = 800)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#number of units sold to each group as percent (crosstab)

# %%
aal.columns
# Out:
# Index(['Date', 'Time', 'State', 'Group', 'Unit', 'Sales'], dtype='object')

# %% [markdown]
# #Time/Sales/Group chart

# %%
px.histogram(aal, x = 'Time', y = 'Sales', color = 'Group', title = 'Total Sales vs. Time', template = 'plotly_dark', text_auto = True, height = 710)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
aal.groupby(['State','Time', 'Group', 'Unit'])['Sales'].sum().sort_values(ascending = False)
# Out:
# State  Time        Group    Unit
#  VIC    Evening    Kids     44      770000
#         Morning    Women    37      740000
#  SA     Afternoon  Women    24      720000
#  VIC    Evening    Men      41      717500
#         Afternoon  Seniors  39      682500
#                                      ...
#  TAS    Afternoon  Women    2         5000
#         Morning    Kids     2         5000
#  NT     Afternoon  Women    2         5000
#  TAS    Afternoon  Kids     2         5000
#                    Men      2         5000
# Name: Sales, Length: 1851, dtype: int64

# %% [markdown]
# #sales by state, group, unit

# %%
px.sunburst(aal, path = ['State', 'Time', 'Group','Unit'], values = 'Sales', title = 'State/Group/Sales/units', template = 'presentation', height=750)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #sales by state, group, unit

# %% [markdown]
# #Number of units sold by state?

# %%
pd.pivot_table(aal, index = ['State','Unit'], columns = 'Group', values = 'Sales', aggfunc = 'sum')
# Out:
# Group        Kids      Men       Seniors   Women
# State Unit
# NSW   12     30000.0  120000.0   90000.0  180000.0
#       13     65000.0   65000.0   97500.0   65000.0
#       14    280000.0  105000.0   70000.0  140000.0
#       15    375000.0  225000.0  375000.0  375000.0
#       16    200000.0  160000.0  360000.0  200000.0
# ...              ...       ...       ...       ...
# WA    11    440000.0  357500.0  412500.0  275000.0
#       12    420000.0  330000.0  240000.0  270000.0
#       13    390000.0  552500.0  487500.0  617500.0
#       14    595000.0  490000.0  560000.0  420000.0
#       15    637500.0  862500.0  637500.0  412500.0
#
# [171 rows x 4 columns]

# %% [markdown]
# #What is the total sale by month?

# %% [markdown]
# ##Firsr make a new month column

# %%
#aal['month'] = pd.DatetimeIndex(aal['Date']).month
aal['month'] = aal['Date'].dt.month

# %%
aal.sample(11)

# %% [markdown]
# #Check the unique month vales

# %%
aal.month.unique()

# %% [markdown]
# #What is the total sale by month for each group?

# %%
pd.pivot_table(aal, index = ['month','Group', 'State'], values = 'Sales', aggfunc = 'sum')#.sample(40)

# %% [markdown]
# #Sales by month

# %%
px.histogram(aal, x = 'month', y = 'Sales', title = 'Sales by Month', template = 'plotly_dark', text_auto = True, height = 850)

# %% [markdown]
# #Sales by Month

# %%
px.histogram(aal, x='month', y='Sales', title='Sales by Month', template='presentation', text_auto=True, facet_row='month', facet_col_wrap=4)

# %% [markdown]
# #sales by month/group/time

# %%
aal.groupby(['month', 'Group', 'Time'])['Sales'].sum()

# %%
pd.pivot_table(aal, index = ['month','Group','Time'], values = 'Sales', aggfunc = 'sum') #nicer representation

# %% [markdown]
# #Making a dataframe for each State

# %% [markdown]
# ##These are the states [' WA', ' NT', ' SA', ' VIC', ' QLD', ' NSW', ' TAS'] in the dataset

# %%
aal.State.unique()

# %% [markdown]
# #dataframe for WA state

# %%
aal_wa = aal[aal.State == ' WA']
aal_wa.head()

# %% [markdown]
# #Total sale by WA state

# %%
pd.pivot_table(aal_wa, index = ['month','Group','Time'], values = 'Sales', aggfunc = 'sum') #nicer representation

# %% [markdown]
# ##Histogram to show the sale

# %%
px.histogram(aal_wa, x = 'month', y = 'Sales', title = 'Sales by Month in WA State', template = 'plotly_dark', text_auto = True, height = 850)

# %%
px.histogram(aal_wa, x = 'month', y = 'Sales', color = 'Group', text_auto=True, height = 830, title = 'WA Sales by Group', template = 'presentation') #nicer representation

# %% [markdown]
# #Units sold to each group

# %%
pd.pivot_table(aal_wa, index = ['Unit'], columns = 'Group', values = 'Sales', aggfunc = 'count')

# %%
px.histogram(aal_wa, x = 'Unit', color = 'Group', title = 'Units Sold  in WA State', template = 'presentation', text_auto = True, height = 750)

# %% [markdown]
# #total units sold to each group by month

# %%
px.histogram(aal_wa, x = 'month', y = 'Unit', color = 'Group', title = 'Number of Units Sold by Group in WA State', template = 'presentation', text_auto = True, height = 700)

# %%
#revenue amount (sale) by unit
pd.pivot_table(aal_wa, index = ['Unit'], columns = 'Group', values = 'Sales', aggfunc = 'sum')

# %% [markdown]
# #Total units sold to each group (WA State)

# %%
pd.crosstab(aal_wa.Unit, aal_wa.Group, margins=True, margins_name='Total')

# %% [markdown]
# #Total sale by each month (in WA State)

# %%
pd.crosstab(aal_wa.month, aal_wa.Group, values = aal_wa.Sales, aggfunc = 'sum', margins=True, margins_name='Total Sale')

# %%
#total units sold  as percent in WA state

pd.crosstab(aal_wa.month, aal_wa.Unit, normalize = True).round(3)

# %%
#units sold bu time group as percent
pd.crosstab(aal_wa.Time, aal_wa.Unit, normalize = True).round(3)

# %%
#total sale by time
pd.crosstab(aal_wa.Time, aal_wa.Group, values = aal_wa.Sales, aggfunc = 'sum', margins=True, margins_name='Total Sale')

# %%
#monthly sale by units to each group
pd.crosstab(aal_wa.month, [aal_wa.Group, aal_wa.Unit])

# %%
#monthly units sold by time
pd.crosstab(aal_wa.Time, [ aal_wa.Unit], margins=True) #NOT WHAT I WANT

# %%
aal.columns

# %% [markdown]
# #total units sold each month

# %%
px.bar(aal_wa, x = 'Unit', y = 'Sales', color = 'Group', title = 'Revenue by Units Sold to each Group in WA State', template = 'presentation', height = 760)

# %%
px.histogram(aal_wa, x = 'Unit', y = 'Sales', color = 'Group', title = 'Total Revenue by Unit to each Group in WA State', template = 'presentation', text_auto = True, height = 750)

# %%
#units sold as percent use crosstab

# %%
px.pie(aal_wa, values = 'Unit', names = 'Group', title = 'Units Sold by Group in WA State', template = 'plotly_dark', height = 800)

# %% [markdown]
# #making a copy of the dataframe

# %%
aal_copy = aal.copy()

# %%
aal_copy.head()

# %%
aal_copy.info()

# %%
from datetime import datetime

# %%
aal_copy.info()

# %% [markdown]
# # Create a new column called 'Month' in aal_copy

# %%
aal_copy["month"] = pd.to_datetime(aal_copy["Date"]).dt.month

# %%
# Create a new column called 'Month' in aal_copy
#aal_copy["month"] = pd.to_datetime(aal_copy["Date"]).month

# Print the first five rows of the 'Month' column
print(aal_copy["month"].head())

# %%
aal_copy.head(7)

# %% [markdown]
# #make a new column year in aal_copy dataframe

# %%
# Create a new column called 'Month' in aal_copy
aal_copy["year"] = pd.to_datetime(aal_copy["Date"]).dt.year

# Print the first five rows of the 'Month' column
print(aal_copy["year"].head())

# %%
aal_copy.sample(11)

# %% [markdown]
# #change Time column datatype to string

# %% [markdown]
# #changing the datatype of multiple columns in dataframe

# %%
aal_copy = aal_copy.astype({'Time':'string', 'State': 'string', 'Group': 'string'})

# %% [markdown]
# ##checking the datatype in the dataframe

# %%
aal_copy.info()

# %% [markdown]
# #make a new column day in the dataframe

# %%
aal[]

# %%
# Extract the week number from the date column
aal['week'] = aal['Date'].dt.isocalendar().week

# %%
aal.week.sample(10)

# %%
aal.week.unique()

# %%
#fig = px.bar(df, x='x', y='y', color='z')
px.bar(aal, x = 'Unit', y = 'Sales', color = 'Group', title = 'Revenue by Units Sold to each Group in WA State', template = 'presentation', height = 760)
fig.update_layout(barmode='group')
fig.show()

# %% [markdown]
# #What is the total units sold to different groups?

# %%
pd.crosstab(aal.Unit, aal.Group,  margins= True, margins_name='Total')#.round(3)

# %% [markdown]
# #How many units sold by state to each group?

# %%
pd.crosstab(aal.State, aal.Group,  values = aal.Unit, aggfunc = 'sum', margins=True, margins_name='Total_Units') .round(3)

# %% [markdown]
# #Total units sold as perents in each state

# %%
pd.crosstab(aal.State, aal.Group,  values = aal.Unit, aggfunc = 'sum', margins=True, margins_name='Total_Units', normalize = True) .round(3)
# Out:
# Group         Kids         Men          Seniors      Women       Total_Units
# State
#  NSW               0.055        0.056        0.053        0.056        0.220
#  NT                0.017        0.017        0.016        0.017        0.066
#  QLD               0.025        0.025        0.024        0.024        0.098
#  SA                0.043        0.043        0.043        0.044        0.173
#  TAS               0.017        0.017        0.017        0.016        0.067
#  VIC               0.077        0.078        0.077        0.078        0.310
#  WA                0.017        0.017        0.016        0.015        0.065
# Total_Units        0.250        0.252        0.247        0.251        1.000
